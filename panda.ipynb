# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rj7shakya/python_ml/main/cleaned_imdb.csv")
df.head()
# Out:
#    Unnamed: 0  color      director_name  num_critic_for_reviews  duration  \
# 0           0  Color      James Cameron                   723.0     178.0
# 1           1  Color     Gore Verbinski                   302.0     169.0
# 2           2  Color         Sam Mendes                   602.0     148.0
# 3           3  Color  Christopher Nolan                   813.0     164.0
# 4           5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross  ... num_user_for_reviews language  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  color      director_name  num_critic_for_reviews  duration  \
# 0           0  Color      James Cameron                   723.0     178.0
# 1           1  Color     Gore Verbinski                   302.0     169.0
# 2           2  Color         Sam Mendes                   602.0     148.0
# 3           3  Color  Christopher Nolan                   813.0     164.0
# 4           5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross  ... num_user_for_reviews language  \
# ...

# %%
df=df.drop(columns=['color'])

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9044\2201091848.py in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.loc[:][['director_name','country']]
# Out:
#           director_name      country
# 0         James Cameron          USA
# 1        Gore Verbinski          USA
# 2            Sam Mendes           UK
# 3     Christopher Nolan          USA
# 4        Andrew Stanton          USA
# ...                 ...          ...
# 4549   Neill Dela Llana  Philippines
# 4550   Robert Rodriguez          USA
# 4551    Anthony Vallone          USA
# 4552       Edward Burns          USA
# 4553           Jon Gunn          USA
#
# [4554 rows x 2 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0     director_name  num_critic_for_reviews  duration  \
# 4549        5034  Neill Dela Llana               35.000000      80.0
# 4550        5035  Robert Rodriguez               56.000000      81.0
# 4551        5036   Anthony Vallone              322.146105      84.0
# 4552        5037      Edward Burns               14.000000      95.0
# 4553        5042          Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4549                      0.0                     0.0     Edgar Tancangco
# 4550                      0.0                     6.0     Peter Marquardt
# 4551                      2.0                     2.0      John Considine
# 4552                      0.0                   133.0  Caitlin FitzGerald
# 4553                     16.0                    16.0    Brian Herzlinger
#
#       actor_1_facebook_likes         gross  \
# 4549                     0.0  7.007100e+04
# ...

# %%
df.loc[:][['movie_title','budget']]
# Out:
#                                     movie_title       budget
# 0                                       Avatar   237000000.0
# 1     Pirates of the Caribbean: At World's End   300000000.0
# 2                                      Spectre   245000000.0
# 3                        The Dark Knight Rises   250000000.0
# 4                                  John Carter   263700000.0
# ...                                         ...          ...
# 4549                                    Cavite        7000.0
# 4550                               El Mariachi        7000.0
# 4551                           The Mongol King        3250.0
# 4552                                 Newlyweds        9000.0
# 4553                         My Date with Drew        1100.0
#
# [4554 rows x 2 columns]

# %%
df.iloc[2:4]
# Out:
#    Unnamed: 0      director_name  num_critic_for_reviews  duration  \
# 2           2         Sam Mendes                   602.0     148.0
# 3           3  Christopher Nolan                   813.0     164.0
#
#    director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 2                      0.0                   161.0    Rory Kinnear
# 3                  22000.0                 23000.0  Christian Bale
#
#    actor_1_facebook_likes        gross                     genres  ...  \
# 2                 11000.0  200074175.0  Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0            Action|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2      2015.0                  393.0        6.8          2.35
# ...

# %%
df.iloc[1][2]
# Out:
# 302.0

# %%
df.iloc[1:2]
# Out:
#    Unnamed: 0   director_name  num_critic_for_reviews  duration  \
# 1           1  Gore Verbinski                   302.0     169.0
#
#    director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 1                    563.0                  1000.0  Orlando Bloom
#
#    actor_1_facebook_likes        gross                    genres  ...  \
# 1                 40000.0  309404152.0  Action|Adventure|Fantasy  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 1               1238.0  English      USA           PG-13  300000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 1      2007.0                 5000.0        7.1          2.35
#
#   movie_facebook_likes
# 1                    0
#
# [1 rows x 28 columns]

# %%
df.iloc[0:1,1]
# Out:
# 0    James Cameron
# Name: director_name, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'James Cameron'

# %%
df.iloc[1:4,1]
# Out:
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# Name: director_name, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0      director_name  num_critic_for_reviews  duration  \
# 0           0      James Cameron                   723.0     178.0
# 1           1     Gore Verbinski                   302.0     169.0
# 2           2         Sam Mendes                   602.0     148.0
# 3           3  Christopher Nolan                   813.0     164.0
# 4           5     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# ...

# %%
df.iloc[1:4,5:8]
# Out:
#    actor_3_facebook_likes    actor_2_name  actor_1_facebook_likes
# 1                  1000.0   Orlando Bloom                 40000.0
# 2                   161.0    Rory Kinnear                 11000.0
# 3                 23000.0  Christian Bale                 27000.0

# %%
index=df.columns.get_loc('director_name')
print(index)
df.iloc[:,index]
# Out:
# 1
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4          Andrew Stanton
#               ...
# 4549     Neill Dela Llana
# 4550     Robert Rodriguez
# 4551      Anthony Vallone
# 4552         Edward Burns
# 4553             Jon Gunn
# Name: director_name, Length: 4554, dtype: object

# %%
df.sort_values(by=['duration'],ascending=False).head()
# Out:
#       Unnamed: 0         director_name  num_critic_for_reviews  duration  \
# 1446        1501       Taylor Hackford                    12.0     330.0
# 1102        1144        Michael Cimino                   102.0     325.0
# 3160        3311   Chatrichalerm Yukol                    31.0     300.0
# 2844        2970     Wolfgang Petersen                    96.0     293.0
# 1514        1571  Francis Ford Coppola                   261.0     289.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 1446                    138.0                   672.0         Jesse Borrego
# 1102                    517.0                   678.0         Sam Waterston
# 3160                      6.0                     6.0  Chatchai Plengpanich
# 2844                    249.0                    18.0    Martin Semmelrogge
# 1514                      0.0                  3000.0         Marlon Brando
#
# ...

# %%
df.sort_values(by=['budget']).loc[:5][['movie_title','budget']]
# Out:
#              movie_title        budget
# 4400          Tarnation   2.180000e+02
# 4553  My Date with Drew   1.100000e+03
# 4551    The Mongol King   3.250000e+03
# 4546              Clean   4.500000e+03
# 4550        El Mariachi   7.000000e+03
# ...                  ...           ...
# 3996  Touching the Void   2.520311e+08
# 4540            Rampage   2.544615e+08
# 3648         Blackthorn   2.575200e+08
# 3288       Spider-Man 3   2.580000e+08
# 5          Spider-Man 3   2.580000e+08
#
# [4504 rows x 2 columns]

# %%
df.sort_values(by=['imdb_score'],ascending=True).tail().loc[:][['movie_title','budget','director_name']]
# Out:
#                           movie_title       budget         director_name
# 4177  The Good, the Bad and the Ugly     1200000.0          Sergio Leone
# 65                   The Dark Knight   185000000.0     Christopher Nolan
# 2714          The Godfather: Part II    13000000.0  Francis Ford Coppola
# 3293                   The Godfather     6000000.0  Francis Ford Coppola
# 1864        The Shawshank Redemption    25000000.0        Frank Darabont

# %%
df.shape
# Out:
# (4554, 28)

# %%
df.dropna?
# Out:
# Signature:
# df.dropna(
#     axis: 'Axis' = 0,
#     how: 'str' = 'any',
#     thresh=None,
#     subset: 'IndexLabel' = None,
#     inplace: 'bool' = False,
# )
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     .. versionchanged:: 1.0.0
#
#        Pass tuple or list to drop on multiple axes.
#        Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
# ...

# %%
df.dropna()
# Out:
#       Unnamed: 0      director_name  num_critic_for_reviews  duration  \
# 0              0      James Cameron              723.000000     178.0
# 1              1     Gore Verbinski              302.000000     169.0
# 2              2         Sam Mendes              602.000000     148.0
# 3              3  Christopher Nolan              813.000000     164.0
# 4              5     Andrew Stanton              462.000000     132.0
# ...          ...                ...                     ...       ...
# 4549        5034   Neill Dela Llana               35.000000      80.0
# 4550        5035   Robert Rodriguez               56.000000      81.0
# 4551        5036    Anthony Vallone              322.146105      84.0
# 4552        5037       Edward Burns               14.000000      95.0
# 4553        5042           Jon Gunn               43.000000      90.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.groupby(['title_year'])['budget','gross'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6088\417069680.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['title_year'])['budget','gross'].mean()
#                   budget         gross
# title_year
# 1916.0      3.859070e+05  5.053711e+07
# 1925.0      2.450000e+05  7.940622e+07
# 1927.0      6.000000e+06  2.643500e+04
# 1929.0      6.452747e+07  1.408975e+06
# 1930.0      3.950000e+06  5.795573e+07
# ...                  ...           ...
# 2012.0      4.801066e+07  5.949147e+07
# 2013.0      4.687214e+07  5.864007e+07
# 2014.0      4.357012e+07  6.298841e+07
# 2015.0      4.926142e+07  6.573173e+07
# 2016.0      6.757634e+07  7.949597e+07
#
# [90 rows x 2 columns]

# %%
df.groupby(['title_year'])['imdb_score','budget'].max()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6088\542273706.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['title_year'])['imdb_score','budget'].max()
#             imdb_score        budget
# title_year
# 1916.0             8.0  3.859070e+05
# 1925.0             8.3  2.450000e+05
# 1927.0             8.3  6.000000e+06
# 1929.0             8.0  1.286759e+08
# 1930.0             7.8  3.950000e+06
# ...                ...           ...
# 2012.0             8.5  6.758157e+08
# 2013.0             8.4  2.250000e+08
# 2014.0             8.7  3.065987e+08
# 2015.0             8.3  2.864922e+08
# 2016.0             8.2  2.500000e+08
#
# [90 rows x 2 columns]

# %%
df.groupby(['director_name']).mean()
# Out:
#                     Unnamed: 0  num_critic_for_reviews  duration  \
# director_name
# A. Raven Cruz           4605.0                     3.0      97.0
# Aaron Hann              4314.0                    29.0      87.0
# Aaron Schneider         3497.0                   160.0     100.0
# Aaron Seltzer           2182.0                    99.0      85.0
# Abel Ferrara            2909.0                    48.0      99.0
# ...                        ...                     ...       ...
# Zak Penn                4452.0                    60.0      94.0
# Zal Batmanglij          4256.5                   168.0     100.5
# Álex de la Iglesia      3242.0                    71.0     104.0
# Émile Gaudreault        3678.0                    67.0      92.0
# Étienne Faure           4848.0                     9.0      98.0
#
#                     director_facebook_likes  actor_3_facebook_likes  \
# director_name
# A. Raven Cruz                           0.0                    94.0
# ...
